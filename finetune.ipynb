# %% [markdown]
# # Fine-tuning

# %%
SOURCE      = "gpt2"
SOURCE_TYPE = "hf"       # "hf" | "fft" | "lora"
DEVICE      = "cuda"
TRAIN_PATH  = "../data/tiny_train.txt"
VAL_PATH    = "../data/tiny_val.txt"
NOTE        = ""

# %%
from load import load_model

model, tokenizer = load_model(SOURCE, SOURCE_TYPE, device=DEVICE)

# %%
# TODO: training loop

# %%
# TODO: save with model.save_pretrained() / tokenizer.save_pretrained()
