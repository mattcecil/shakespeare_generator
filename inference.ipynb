# %% [markdown]
# # Shakespeare Generator — Inference
#
# Generate text from any model via `load_model`.
#
# Set `SOURCE` and `SOURCE_TYPE` in the config cell, then run all cells.
#
# | source_type | source example |
# |---|---|
# | `"custom"` | `"checkpoints/my-run.pt"` |
# | `"hf"` | `"gpt2"` or `"EleutherAI/pythia-70m"` |
# | `"fft"` | `"checkpoints/my-fft/"` |
# | `"lora"` | `"checkpoints/my-lora/"` |

# %% [markdown]
# ## Load Model

# %%
SOURCE      = "gpt2"   #"checkpoints/balmy-spaceship-9.pt"
SOURCE_TYPE = "hf"       # "custom" | "hf" | "fft" | "lora"
DEVICE      = "cuda"

from load import load_model

model, tokenizer = load_model(SOURCE, SOURCE_TYPE, device=DEVICE)
print(f"Loaded {SOURCE_TYPE}: {SOURCE}")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Loaded hf: gpt2

# %%
from generate import generate_text

prompt = """SEBASTIAN:
You were kneel'd to and importuned otherwise
By all of us, and the fair soul herself
Weigh'd between loathness and obedience, at
Which end o' the beam should bow. We have lost your
son,
I fear, for ever: Milan and Naples have
More widows in them of this business' making
Than we bring men to comfort them:
The fault's your own.

ALONSO:
So is the dear'st o' the loss.

GONZALO:
My lord Sebastian,
The truth you speak doth lack some gentleness
And time to speak it in: you rub the sore,
When you should bring the plaster.

SEBASTIAN:
Very well."""

print(generate_text(model, tokenizer, prompt,
                    max_new_tokens=500, temperature=0.8))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ALONSO:
#
# And if you must see a man's sorrow,
#
# He could choose a friend to bring.
#
# SEBASTIAN:
#
# Or you would find him not a virgin
#
# O' the soul, it would be too much,
#
# For you would not trust to their lips
#
# When the wise and noble
#
# Dream not of love,
#
# And as for that grief.
#
# ALONSO:
#
# So it is I'll not be content
#
# To sail, for if the noble
#
# Was satisfied with a vow,
#
# We'd see you on the sea.
#
# GLENN GREENWALD:
#
# Your generous spirits,
#
# It roused me that I found
#
# Miles to explore the waters.
#
# EGG GRUBOWSKI:
#
# I am, too, very much impelled to do.
#
# GLENN GREENWALD:
#
# I'm a fool to leave, I bludgeon'd
#
# I shall never have the boon of eternity.
#
# EGG GRUBOWSKI:
#
# I was under your command, O gentle Jove;
#
# I may myself make out
#
# Miles on our just way, but I
#
# Will not go back to your villages
#
# Besides all the great reproach
#
# That you have of fair women,
#
# And have promised to not to disturb,
#
# And with all your great splendour
#
# I shall be no more.
#
# GLENN GREENWALD:
#
# I think, too, that your reason
#
# Is most fitly to keep quiet,
#
# I need not a little prayer,
#
# But you will not disturb your friends.
#
# EGG GRUBOWSKI:
#
# You will not disturb us,
#
# I thank you very much
#
# For having a warm heart,
#
# For a generous hand,
#
# Of which I understand that
#
# I had long to be a little afraid
#
# Of old age.
#
# GLENN GREENWALD:
#
# You cannot wait. I have been
#
# Naught but sleep'd to sleep.
#
# GLENN GREENWALD:
#
# It would be you both
#
# But the poor and the feeble,
#
# Your own hearts so drugged with their shame
#
# That you will soon find the comfort
