# %% [markdown]
# # Shakespeare Generator — Inference
#
# Evaluate and generate text from any model:
# - **Custom** — scratch-trained `Transformer` from `transformer.ipynb`
# - **HuggingFace** — small pre-trained LM (e.g. GPT-2, Pythia)
# - **SFT** — HuggingFace model fine-tuned with `sft.ipynb`
#
# Set `MODEL_TYPE` and the relevant path/name in the config cell, then run all cells.

# %% [markdown]
# ## Load Model

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2").eval().to("cuda")
# Out:
# ...
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
inputs = tokenizer("To be or not to be", return_tensors="pt").to("cuda")

output_ids = model.generate(
    input_ids=inputs["input_ids"], 
    attention_mask=inputs["attention_mask"], 
    max_new_tokens=200,
    do_sample=True,
    temperature=1.0,
)

print(tokenizer.decode(output_ids[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# To be or not to be a good citizen and therefore a good citizen is to pay taxes. And here it needs more evidence.
#
# In 1992, in an effort to keep things going for George, a federal judge handed a decision to a former congressman of Texas who had made a lot of money off his personal wealth.
#
# "The District Court found that the congressman's personal property was not worth property," said D.C. Circuit Judge Derryn Wilson, who said that the congressman's taxes were actually worth something.
#
# Wilson said that under the laws he was told, all that property can be used to repay debts. His decision didn't go over well with many in the Beltway.
#
# "You could probably think of it as saying to myself, 'Hey, you're too old, you're too wealthy,' but that's a pretty clear case of where I'm at right now," said Michael Binder, president of the Federalist Society, an anti-government watchdog group that called Wilson
